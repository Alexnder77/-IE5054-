# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
import os
import datetime as dt
import itertools
import networkx as nx

# %%
test_df = pd.read_csv("test_source_events.csv")
train_df = pd.read_csv("train_source_events.csv")

# %% [markdown]
# ## Step 1: Calculate Drama Popularity Metrics

# %%
# Calculate total views for each drama
drama_total_views = train_df['title_id'].value_counts()

# Calculate unique users who watched each drama
drama_unique_users = train_df.groupby('title_id')['user_id'].nunique()

# Calculate average completion ratio for each drama
drama_avg_completion_ratio = train_df.groupby('title_id')['played_duration'].mean()

# %% [markdown]
# ## Step 2: Filter Drama Connections Based on Shared Users

# %%
# Calculate the median number of shared users as the threshold
shared_users_threshold = train_df.groupby(['title_id'])['user_id'].nunique().median()

# Create drama connections dataframe
drama_connections = train_df.groupby('user_id')['title_id'].apply(set).reset_index()

# Generate drama pairs based on shared users
drama_pairs = (
    drama_connections['title_id']
    .apply(lambda x: [(a, b) for a, b in itertools.combinations(x, 2)])
    .explode()
)

# Filter drama pairs based on shared users threshold
filtered_drama_pairs = (
    drama_pairs.groupby(drama_pairs)
    .size()
    .reset_index(name='shared_users')
    .query('shared_users >= @shared_users_threshold')
)

# %% [markdown]
# ## Step 3: Apply DeepWalk Algorithm for Drama Embeddings
#
# DeepWalk is a graph embedding algorithm that learns low-dimensional representations (embeddings) of nodes in a graph.
# This step applies the DeepWalk algorithm to the graph formed by the filtered drama pairs.
# The code uses the DeepWalk class (or a similar graph embedding algorithm) to run the DeepWalk algorithm and obtain embeddings for the dramas.
# The resulting drama embeddings capture the underlying structure and relationships of the dramas based on their shared viewership patterns.
# These embeddings can be used for various downstream tasks, such as similarity analysis, recommendation systems, or clustering of dramas.

# %%
import networkx as nx
from node2vec import Node2Vec

# Create graph from filtered drama pairs
G = nx.Graph()
G.add_edges_from(filtered_drama_pairs.to_numpy())

# Generate random walks on the graph using Node2Vec
node2vec = Node2Vec(G, dimensions=32, walk_length=80, num_walks=10)
model = node2vec.fit(window=10, min_count=0, sg=1, workers=1)

# Obtain drama embeddings
drama_embeddings = {int(node): model.wv[str(node)] for node in G.nodes()}
# Out:
# Computing transition probabilities:   0%|          | 0/192712 [00:00<?, ?it/s]

# %%
# Step 4: Group by user and derive user-level features
user_grouped = train_df.groupby('user_id')
user_features = user_grouped.agg({
    'played_duration': ['sum', 'count'],
    'title_id': 'nunique'
})
user_features.columns = ['total_duration', 'total_views', 'unique_dramas']

# Step 5: Merge all features with train_df based on user_id
train_merged = pd.merge(train_df, drama_counts, on='title_id', how='left')
train_merged = pd.merge(train_merged, drama_unique_users, on='title_id', how='left')
train_merged = pd.merge(train_merged, drama_total_episodes, on='title_id', how='left')
train_merged = pd.merge(train_merged, drama_avg_completion_ratio, on='title_id', how='left')
train_merged = pd.merge(train_merged, user_features, on='user_id', how='left')

# Step 6: Merge drama embeddings with train_merged based on title_id
train_merged = pd.merge(train_merged, pd.DataFrame.from_dict(drama_embeddings, orient='index'), left_on='title_id', right_index=True, how='left')

# Step 7: Format the data with one user_id per row
user_features_final = user_grouped[['user_id', 'total_duration', 'total_views', 'unique_dramas']].first().reset_index(drop=True)
train_final = pd.merge(user_features_final, train_merged.drop_duplicates(subset=['user_id']), on='user_id', how='inner')

# Step 8: Train your prediction model using train_final

# %%
# save the result to file
df.to_csv("Procecssed_test_source_events", index=True)
# Out:
# Extracting frequency counts for time=29201
# Extracting frequency counts for time=10103
# Extracting frequency counts for time=13313
# Extracting frequency counts for time=12271
# Extracting frequency counts for time=18061
# Extracting frequency counts for time=19153
# Extracting frequency counts for time=19151
# Extracting frequency counts for time=37143
# Extracting frequency counts for time=16211
# Extracting frequency counts for time=33180
# Extracting frequency counts for time=05051
# Extracting frequency counts for time=07150
# Extracting frequency counts for time=07151
# Extracting frequency counts for time=08211
# Extracting frequency counts for time=13302
# Extracting frequency counts for time=15162
# Extracting frequency counts for time=18020
# Extracting frequency counts for time=20192
# Extracting frequency counts for time=21281
# Extracting frequency counts for time=03173
# Extracting frequency counts for time=25203
# Extracting frequency counts for time=19100
# Extracting frequency counts for time=08210
# Extracting frequency counts for time=04250
# Extracting frequency counts for time=16180
# Extracting frequency counts for time=07160
# Extracting frequency counts for time=02163
# Extracting frequency counts for time=32123
# Extracting frequency counts for time=12232
# Extracting frequency counts for time=31050
# Extracting frequency counts for time=16193
# Extracting frequency counts for time=07172
# Extracting frequency counts for time=32111
# Extracting frequency counts for time=21290
# Extracting frequency counts for time=21232
# Extracting frequency counts for time=14080
# Extracting frequency counts for time=28143
# Extracting frequency counts for time=08251
# Extracting frequency counts for time=18033
# Extracting frequency counts for time=01032
# Extracting frequency counts for time=27051
# Extracting frequency counts for time=08261
# Extracting frequency counts for time=17251
# Extracting frequency counts for time=20203
# Extracting frequency counts for time=16203
# Extracting frequency counts for time=21233
# Extracting frequency counts for time=16213
# Extracting frequency counts for time=12270
# Extracting frequency counts for time=31053
# Extracting frequency counts for time=32110
# Extracting frequency counts for time=29190
# Extracting frequency counts for time=17283
# Extracting frequency counts for time=28161
# Extracting frequency counts for time=02133
# Extracting frequency counts for time=12210
# Extracting frequency counts for time=29203
# Extracting frequency counts for time=35310
# Extracting frequency counts for time=16233
# Extracting frequency counts for time=33182
# Extracting frequency counts for time=21280
# Extracting frequency counts for time=31052
# Extracting frequency counts for time=17253
# Extracting frequency counts for time=23123
# Extracting frequency counts for time=21272
# Extracting frequency counts for time=23120
# Extracting frequency counts for time=23091
# Extracting frequency counts for time=15133
# Extracting frequency counts for time=30310
# Extracting frequency counts for time=21263
# Extracting frequency counts for time=08272
# Extracting frequency counts for time=23083
# Extracting frequency counts for time=12243
# Extracting frequency counts for time=17012
# Extracting frequency counts for time=09011
# Extracting frequency counts for time=22300
# Extracting frequency counts for time=11152
# Extracting frequency counts for time=17010
# Extracting frequency counts for time=27092
# Extracting frequency counts for time=01071
# Extracting frequency counts for time=07140
# Extracting frequency counts for time=11183
# Extracting frequency counts for time=32143
# Extracting frequency counts for time=01081
# Extracting frequency counts for time=06130
# Extracting frequency counts for time=11192
# Extracting frequency counts for time=06083
# Extracting frequency counts for time=01070
# Extracting frequency counts for time=24171
# Extracting frequency counts for time=33203
# Extracting frequency counts for time=23111
# Extracting frequency counts for time=19133
# Extracting frequency counts for time=25202
# Extracting frequency counts for time=33210
# Extracting frequency counts for time=09031
# Extracting frequency counts for time=18070
# Extracting frequency counts for time=13031
# Extracting frequency counts for time=28160
# Extracting frequency counts for time=10072
# Extracting frequency counts for time=17270
# Extracting frequency counts for time=52022
# Extracting frequency counts for time=35303
# Extracting frequency counts for time=27090
# Extracting frequency counts for time=34263
# Extracting frequency counts for time=07201
# Extracting frequency counts for time=03201
# Extracting frequency counts for time=24190
# Extracting frequency counts for time=30311
# Extracting frequency counts for time=17013
# Extracting frequency counts for time=32093
# Extracting frequency counts for time=30313
# Extracting frequency counts for time=17293
# Extracting frequency counts for time=35022
# Extracting frequency counts for time=13010
# Extracting frequency counts for time=22040
# Extracting frequency counts for time=24182
# Extracting frequency counts for time=08231
# Extracting frequency counts for time=26273
# Extracting frequency counts for time=30291
# Extracting frequency counts for time=11201
# Extracting frequency counts for time=09042
# Extracting frequency counts for time=19131
# Extracting frequency counts for time=15132
# Extracting frequency counts for time=28163
# Extracting frequency counts for time=09282
# Extracting frequency counts for time=15123
# Extracting frequency counts for time=36113
# Extracting frequency counts for time=16240
# Extracting frequency counts for time=34251
# Extracting frequency counts for time=26022
# Extracting frequency counts for time=04260
# Extracting frequency counts for time=12262
# Extracting frequency counts for time=36060
# Extracting frequency counts for time=18022
# Extracting frequency counts for time=01092
# Extracting frequency counts for time=20193
# Extracting frequency counts for time=25233
# Extracting frequency counts for time=03212
# Extracting frequency counts for time=20201
# Extracting frequency counts for time=07173
# Extracting frequency counts for time=12212
# Extracting frequency counts for time=34223
# Extracting frequency counts for time=04293
# Extracting frequency counts for time=19111
# Extracting frequency counts for time=36090
# Extracting frequency counts for time=25211
# Extracting frequency counts for time=24161
# Extracting frequency counts for time=29242
# Extracting frequency counts for time=30273
# Extracting frequency counts for time=18052
# Extracting frequency counts for time=18030
# Extracting frequency counts for time=13030
# Extracting frequency counts for time=12260
# Extracting frequency counts for time=01061
# Extracting frequency counts for time=21261
# Extracting frequency counts for time=09033
# Extracting frequency counts for time=24193
# Extracting frequency counts for time=21230
# Extracting frequency counts for time=06103
# Extracting frequency counts for time=01073
# Extracting frequency counts for time=06102
# Extracting frequency counts for time=08220
# Extracting frequency counts for time=23102
# Extracting frequency counts for time=10122
# Extracting frequency counts for time=14063
# Extracting frequency counts for time=08262
# Extracting frequency counts for time=15111
# Extracting frequency counts for time=25243
# Extracting frequency counts for time=14062
# Extracting frequency counts for time=26281
# Extracting frequency counts for time=06123
# Extracting frequency counts for time=13282
# Extracting frequency counts for time=32120
# Extracting frequency counts for time=32112
# Extracting frequency counts for time=32092
# Extracting frequency counts for time=36082
# Extracting frequency counts for time=14103
# Extracting frequency counts for time=13013
# Extracting frequency counts for time=09010
# Extracting frequency counts for time=04253
# Extracting frequency counts for time=10133
# Extracting frequency counts for time=13033
# Extracting frequency counts for time=21242
# Extracting frequency counts for time=12242
# Extracting frequency counts for time=18073
# Extracting frequency counts for time=21282
# Extracting frequency counts for time=37123
# Extracting frequency counts for time=26012
# Extracting frequency counts for time=03231
# Extracting frequency counts for time=16190
# Extracting frequency counts for time=29202
# Extracting frequency counts for time=37132
# Extracting frequency counts for time=05022
# Extracting frequency counts for time=16202
# Extracting frequency counts for time=16221
# Extracting frequency counts for time=10112
# Extracting frequency counts for time=11191
# Extracting frequency counts for time=30261
# Extracting frequency counts for time=01063
# Extracting frequency counts for time=14071
# Extracting frequency counts for time=02110
# Extracting frequency counts for time=21251
# Extracting frequency counts for time=27100
# Extracting frequency counts for time=05020
# Extracting frequency counts for time=11182
# Extracting frequency counts for time=31063
# Extracting frequency counts for time=25221
# Extracting frequency counts for time=24191
# Extracting frequency counts for time=37121
# Extracting frequency counts for time=33171
# Extracting frequency counts for time=06120
# Extracting frequency counts for time=07142
# Extracting frequency counts for time=34231
# Extracting frequency counts for time=10121
# Extracting frequency counts for time=19102
# Extracting frequency counts for time=08222
# Extracting frequency counts for time=30281
# Extracting frequency counts for time=11163
# Extracting frequency counts for time=29193
# Extracting frequency counts for time=21240
# Extracting frequency counts for time=16222
# Extracting frequency counts for time=26280
# Extracting frequency counts for time=09030
# Extracting frequency counts for time=24140
# Extracting frequency counts for time=07170
# Extracting frequency counts for time=17271
# Extracting frequency counts for time=13032
# Extracting frequency counts for time=10070
# Extracting frequency counts for time=25262
# Extracting frequency counts for time=52020
# Extracting frequency counts for time=21262
# Extracting frequency counts for time=24151
# Extracting frequency counts for time=33193
# Extracting frequency counts for time=24142
# Extracting frequency counts for time=02120
# Extracting frequency counts for time=18040
# Extracting frequency counts for time=34240
# Extracting frequency counts for time=17250
# Extracting frequency counts for time=34260
# Extracting frequency counts for time=03181
# Extracting frequency counts for time=14092
# Extracting frequency counts for time=04261
# Extracting frequency counts for time=27081
# Extracting frequency counts for time=23063
# Extracting frequency counts for time=18050
# Extracting frequency counts for time=17303
# Extracting frequency counts for time=10130
# Extracting frequency counts for time=04252
# Extracting frequency counts for time=05052
# Extracting frequency counts for time=15161
# Extracting frequency counts for time=09283
# Extracting frequency counts for time=25251
# Extracting frequency counts for time=20181
# Extracting frequency counts for time=33200
# Extracting frequency counts for time=03230
# Extracting frequency counts for time=18062
# Extracting frequency counts for time=30300
# Extracting frequency counts for time=30272
# Extracting frequency counts for time=11153
# Extracting frequency counts for time=05042
# Extracting frequency counts for time=37142
# Extracting frequency counts for time=36071
# Extracting frequency counts for time=31021
# Extracting frequency counts for time=06133
# Extracting frequency counts for time=09053
# Extracting frequency counts for time=24170
# Extracting frequency counts for time=01052
# Extracting frequency counts for time=15151
# Extracting frequency counts for time=18041
# Extracting frequency counts for time=07180
# Extracting frequency counts for time=28121
# Extracting frequency counts for time=18051
# Extracting frequency counts for time=09041
# Extracting frequency counts for time=16212
# Extracting frequency counts for time=07193
# Extracting frequency counts for time=22030
# Extracting frequency counts for time=36052
# Extracting frequency counts for time=15170
# Extracting frequency counts for time=32142
# Extracting frequency counts for time=17291
# Extracting frequency counts for time=09052
# Extracting frequency counts for time=26033
# Extracting frequency counts for time=34271
# Extracting frequency counts for time=14051
# Extracting frequency counts for time=03211
# Extracting frequency counts for time=36091
# Extracting frequency counts for time=15171
# Extracting frequency counts for time=35031
# Extracting frequency counts for time=35291
# Extracting frequency counts for time=20202
# Extracting frequency counts for time=52013
# Extracting frequency counts for time=28173
# Extracting frequency counts for time=07171
# Extracting frequency counts for time=11150
# Extracting frequency counts for time=23080
# Extracting frequency counts for time=12241
# Extracting frequency counts for time=34250
# Extracting frequency counts for time=52011
# Extracting frequency counts for time=04291
# Extracting frequency counts for time=28131
# Extracting frequency counts for time=31071
# Extracting frequency counts for time=30280
# Extracting frequency counts for time=26013
# Extracting frequency counts for time=33202
# Extracting frequency counts for time=22303
# Extracting frequency counts for time=22042
# Extracting frequency counts for time=04240
# Extracting frequency counts for time=16210
# Extracting frequency counts for time=35312
# Extracting frequency counts for time=14040
# Extracting frequency counts for time=01062
# Extracting frequency counts for time=37120
# Extracting frequency counts for time=20213
# Extracting frequency counts for time=01043
# Extracting frequency counts for time=24130
# Extracting frequency counts for time=52021
# Extracting frequency counts for time=09281
# Extracting frequency counts for time=37140
# Extracting frequency counts for time=17252
# Extracting frequency counts for time=02161
# Extracting frequency counts for time=15163
# Extracting frequency counts for time=32101
# Extracting frequency counts for time=05312
# Extracting frequency counts for time=01093
# Extracting frequency counts for time=29211
# Extracting frequency counts for time=31070
# Extracting frequency counts for time=13301
# Extracting frequency counts for time=05013
# Extracting frequency counts for time=28141
# Extracting frequency counts for time=35301
# Extracting frequency counts for time=15112
# Extracting frequency counts for time=01082
# Extracting frequency counts for time=19121
# Extracting frequency counts for time=02140
# Extracting frequency counts for time=31023
# Extracting frequency counts for time=12211
# Extracting frequency counts for time=08263
# Extracting frequency counts for time=23103
# Extracting frequency counts for time=08232
# Extracting frequency counts for time=35041
# Extracting frequency counts for time=34273
# Extracting frequency counts for time=26303
# Extracting frequency counts for time=25220
# Extracting frequency counts for time=06071
# Extracting frequency counts for time=04273
# Extracting frequency counts for time=26282
# Extracting frequency counts for time=13300
# Extracting frequency counts for time=27072
# Extracting frequency counts for time=29222
# Extracting frequency counts for time=12221
# Extracting frequency counts for time=34281
# Extracting frequency counts for time=06113
# Extracting frequency counts for time=28113
# Extracting frequency counts for time=08242
# Extracting frequency counts for time=09061
# Extracting frequency counts for time=14041
# Extracting frequency counts for time=11170
# Extracting frequency counts for time=29212
# Extracting frequency counts for time=11171
# Extracting frequency counts for time=06121
# Extracting frequency counts for time=29210
# Extracting frequency counts for time=02131
# Extracting frequency counts for time=28153
# Extracting frequency counts for time=22301
# Extracting frequency counts for time=36051
# Extracting frequency counts for time=22311
# Extracting frequency counts for time=31032
# Extracting frequency counts for time=18071
# Extracting frequency counts for time=33183
# Extracting frequency counts for time=36101
# Extracting frequency counts for time=23121
# Extracting frequency counts for time=14053
# Extracting frequency counts for time=13020
# Extracting frequency counts for time=35011
# Extracting frequency counts for time=22013
# Extracting frequency counts for time=32132
# Extracting frequency counts for time=19093
# Extracting frequency counts for time=23090
# Extracting frequency counts for time=33161
# Extracting frequency counts for time=25260
# Extracting frequency counts for time=34252
# Extracting frequency counts for time=03180
# Extracting frequency counts for time=35030
# Extracting frequency counts for time=09062
# Extracting frequency counts for time=36103
# Extracting frequency counts for time=24181
# Extracting frequency counts for time=19091
# Extracting frequency counts for time=14043
# Extracting frequency counts for time=34270
# Extracting frequency counts for time=07192
# Extracting frequency counts for time=10111
# Extracting frequency counts for time=15122
# Extracting frequency counts for time=13011
# Extracting frequency counts for time=36083
# Extracting frequency counts for time=04303
# Extracting frequency counts for time=10131
# Extracting frequency counts for time=08273
# Extracting frequency counts for time=12252
# Extracting frequency counts for time=01090
# Extracting frequency counts for time=21270
# Extracting frequency counts for time=30282
# Extracting frequency counts for time=20191
# Extracting frequency counts for time=36111
# Extracting frequency counts for time=16182
# Extracting frequency counts for time=25212
# Extracting frequency counts for time=34232
# Extracting frequency counts for time=16232
# Extracting frequency counts for time=33170
# Extracting frequency counts for time=24133
# Extracting frequency counts for time=29220
# Extracting frequency counts for time=02130
# Extracting frequency counts for time=37160
# Extracting frequency counts for time=03182
# Extracting frequency counts for time=18042
# Extracting frequency counts for time=22020
# Extracting frequency counts for time=01041
# Extracting frequency counts for time=05060
# Extracting frequency counts for time=07163
# Extracting frequency counts for time=37141
# Extracting frequency counts for time=19092
# Extracting frequency counts for time=31072
# Extracting frequency counts for time=22011
# Extracting frequency counts for time=32083
# Extracting frequency counts for time=28132
# Extracting frequency counts for time=10110
# Extracting frequency counts for time=10120
# Extracting frequency counts for time=19113
# Extracting frequency counts for time=12240
# Extracting frequency counts for time=26030
# Extracting frequency counts for time=18072
# Extracting frequency counts for time=35032
# Extracting frequency counts for time=23093
# Extracting frequency counts for time=06092
# Extracting frequency counts for time=04241
# Extracting frequency counts for time=02152
# Extracting frequency counts for time=16201
# Extracting frequency counts for time=25250
# Extracting frequency counts for time=26300
# Extracting frequency counts for time=19110
# Extracting frequency counts for time=07141
# Extracting frequency counts for time=27060
# Extracting frequency counts for time=18083
# Extracting frequency counts for time=06090
# Extracting frequency counts for time=32141
# Extracting frequency counts for time=10083
# Extracting frequency counts for time=35033
# Extracting frequency counts for time=05012
# Extracting frequency counts for time=27103
# Extracting frequency counts for time=20190
# Extracting frequency counts for time=08230
# Extracting frequency counts for time=27082
# Extracting frequency counts for time=13311
# Extracting frequency counts for time=33163
# Extracting frequency counts for time=11172
# Extracting frequency counts for time=20200
# Extracting frequency counts for time=01091
# Extracting frequency counts for time=30253
# Extracting frequency counts for time=24160
# Extracting frequency counts for time=14070
# Extracting frequency counts for time=35300
# Extracting frequency counts for time=10080
# Extracting frequency counts for time=22012
# Extracting frequency counts for time=29181
# Extracting frequency counts for time=22041
# Extracting frequency counts for time=11151
# Extracting frequency counts for time=03190
# Extracting frequency counts for time=09032
# Extracting frequency counts for time=28152
# Extracting frequency counts for time=05021
# Extracting frequency counts for time=30290
# Extracting frequency counts for time=36102
# Extracting frequency counts for time=32113
# Extracting frequency counts for time=12231
# Extracting frequency counts for time=13021
# Extracting frequency counts for time=10093
# Extracting frequency counts for time=12250
# Extracting frequency counts for time=05063
# Extracting frequency counts for time=25232
# Extracting frequency counts for time=25263
# Extracting frequency counts for time=12230
# Extracting frequency counts for time=07191
# Extracting frequency counts for time=10101
# Extracting frequency counts for time=33212
# Extracting frequency counts for time=32080
# Extracting frequency counts for time=22052
# Extracting frequency counts for time=21253
# Extracting frequency counts for time=31060
# Extracting frequency counts for time=04302
# Extracting frequency counts for time=35292
# Extracting frequency counts for time=10100
# Extracting frequency counts for time=34233
# Extracting frequency counts for time=07152
# Extracting frequency counts for time=37130
# Extracting frequency counts for time=17261
# Extracting frequency counts for time=11200
# Extracting frequency counts for time=52010
# Extracting frequency counts for time=36062
# Extracting frequency counts for time=32133
# Extracting frequency counts for time=22050
# Extracting frequency counts for time=21293
# Extracting frequency counts for time=07181
# Extracting frequency counts for time=01030
# Extracting frequency counts for time=06132
# Extracting frequency counts for time=30301
# Extracting frequency counts for time=34253
# Extracting frequency counts for time=35043
# Extracting frequency counts for time=06093
# Extracting frequency counts for time=02132
# Extracting frequency counts for time=29240
# Extracting frequency counts for time=22302
# Extracting frequency counts for time=18080
# Extracting frequency counts for time=23110
# Extracting frequency counts for time=14090
# Extracting frequency counts for time=09043
# Extracting frequency counts for time=15130
# Extracting frequency counts for time=27063
# Extracting frequency counts for time=22051
# Extracting frequency counts for time=26291
# Extracting frequency counts for time=23092
# Extracting frequency counts for time=10091
# Extracting frequency counts for time=22310
# Extracting frequency counts for time=24152
# Extracting frequency counts for time=18060
# Extracting frequency counts for time=06101
# Extracting frequency counts for time=15120
# Extracting frequency counts for time=28171
# Extracting frequency counts for time=32090
# Extracting frequency counts for time=32103
# Extracting frequency counts for time=04251
# Extracting frequency counts for time=25253
# Extracting frequency counts for time=34220
# Extracting frequency counts for time=36100
# Extracting frequency counts for time=03223
# Extracting frequency counts for time=10073
# Extracting frequency counts for time=35290
# Extracting frequency counts for time=17280
# Extracting frequency counts for time=04271
# Extracting frequency counts for time=31042
# Extracting frequency counts for time=19112
# Extracting frequency counts for time=06100
# Extracting frequency counts for time=23061
# Extracting frequency counts for time=26283
# Extracting frequency counts for time=28140
# Extracting frequency counts for time=07200
# Extracting frequency counts for time=20171
# Extracting frequency counts for time=21291
# Extracting frequency counts for time=21250
# Extracting frequency counts for time=08233
# Extracting frequency counts for time=23082
# Extracting frequency counts for time=13290
# Extracting frequency counts for time=31051
# Extracting frequency counts for time=16191
# Extracting frequency counts for time=11180
# Extracting frequency counts for time=33150
# Extracting frequency counts for time=29183
# Extracting frequency counts for time=03192
# Extracting frequency counts for time=13303
# Extracting frequency counts for time=11160
# Extracting frequency counts for time=22023
# Extracting frequency counts for time=03193
# Extracting frequency counts for time=35313
# Extracting frequency counts for time=05041
# Extracting frequency counts for time=30271
# Extracting frequency counts for time=01053
# Extracting frequency counts for time=37150
# Extracting frequency counts for time=14083
# Extracting frequency counts for time=31012
# Extracting frequency counts for time=18053
# Extracting frequency counts for time=31010
# Extracting frequency counts for time=29191
# Extracting frequency counts for time=31040
# Extracting frequency counts for time=33151
# Extracting frequency counts for time=17281
# Extracting frequency counts for time=09023
# Extracting frequency counts for time=23112
# Extracting frequency counts for time=31061
# Extracting frequency counts for time=33191
# Extracting frequency counts for time=02150
# Extracting frequency counts for time=35311
# Extracting frequency counts for time=36053
# Extracting frequency counts for time=35040
# Extracting frequency counts for time=14060
# Extracting frequency counts for time=17282
# Extracting frequency counts for time=03172
# Extracting frequency counts for time=22031
# Extracting frequency counts for time=32091
# Extracting frequency counts for time=18032
# Extracting frequency counts for time=28120
# Extracting frequency counts for time=30263
# Extracting frequency counts for time=01083
# Extracting frequency counts for time=24183
# Extracting frequency counts for time=23100
# Extracting frequency counts for time=34242
# Extracting frequency counts for time=34243
# Extracting frequency counts for time=19130
# Extracting frequency counts for time=12261
# Extracting frequency counts for time=28112
# Extracting frequency counts for time=02113
# Extracting frequency counts for time=23101
# Extracting frequency counts for time=16192
# Extracting frequency counts for time=24132
# Extracting frequency counts for time=15110
# Extracting frequency counts for time=31013
# Extracting frequency counts for time=29182
# Extracting frequency counts for time=35012
# Extracting frequency counts for time=29192
# Extracting frequency counts for time=33211
# Extracting frequency counts for time=08260
# Extracting frequency counts for time=15173
# Extracting frequency counts for time=20223
# Extracting frequency counts for time=25261
# Extracting frequency counts for time=10090
# Extracting frequency counts for time=07203
# Extracting frequency counts for time=23122
# Extracting frequency counts for time=04280
# Extracting frequency counts for time=05043
# Extracting frequency counts for time=11162
# Extracting frequency counts for time=33172
# Extracting frequency counts for time=22312
# Extracting frequency counts for time=24141
# Extracting frequency counts for time=21252
# Extracting frequency counts for time=08221
# Extracting frequency counts for time=15140
# Extracting frequency counts for time=06081
# Extracting frequency counts for time=32140
# Extracting frequency counts for time=20170
# Extracting frequency counts for time=24180
# Extracting frequency counts for time=20220
# Extracting frequency counts for time=37152
# Extracting frequency counts for time=03191
# Extracting frequency counts for time=08212
# Extracting frequency counts for time=24153
# Extracting frequency counts for time=25222
# Extracting frequency counts for time=09060
# Extracting frequency counts for time=05050
# Extracting frequency counts for time=31043
# Extracting frequency counts for time=23062
# Extracting frequency counts for time=11190
# Extracting frequency counts for time=10102
# Extracting frequency counts for time=24131
# Extracting frequency counts for time=24162
# Extracting frequency counts for time=36063
# Extracting frequency counts for time=31033
# Extracting frequency counts for time=27041
# Extracting frequency counts for time=09013
# Extracting frequency counts for time=05313
# Extracting frequency counts for time=13281
# Extracting frequency counts for time=27101
# Extracting frequency counts for time=27050
# Extracting frequency counts for time=14093
# Extracting frequency counts for time=02121
# Extracting frequency counts for time=24150
# Extracting frequency counts for time=08252
# Extracting frequency counts for time=27070
# Extracting frequency counts for time=36092
# Extracting frequency counts for time=19090
# Extracting frequency counts for time=10132
# Extracting frequency counts for time=03171
# Extracting frequency counts for time=32100
# Extracting frequency counts for time=28170
# Extracting frequency counts for time=09012
# Extracting frequency counts for time=10092
# Extracting frequency counts for time=01080
# Extracting frequency counts for time=22022
# Extracting frequency counts for time=34280
# Extracting frequency counts for time=01033
# Extracting frequency counts for time=27052
# Extracting frequency counts for time=24173
# Extracting frequency counts for time=26010
# Extracting frequency counts for time=36112
# Extracting frequency counts for time=07153
# Extracting frequency counts for time=08250
# Extracting frequency counts for time=07161
# Extracting frequency counts for time=05030
# Extracting frequency counts for time=28162
# Extracting frequency counts for time=31062
# Extracting frequency counts for time=28111
# Extracting frequency counts for time=10123
# Extracting frequency counts for time=13312
# Extracting frequency counts for time=25241
# Extracting frequency counts for time=10081
# Extracting frequency counts for time=18063
# Extracting frequency counts for time=32082
# Extracting frequency counts for time=17273
# Extracting frequency counts for time=35020
# Extracting frequency counts for time=04262
# Extracting frequency counts for time=08271
# Extracting frequency counts for time=23070
# Extracting frequency counts for time=13291
# Extracting frequency counts for time=29213
# Extracting frequency counts for time=25240
# Extracting frequency counts for time=35302
# Extracting frequency counts for time=21241
# Extracting frequency counts for time=34282
# Extracting frequency counts for time=28122
# Extracting frequency counts for time=02142
# Extracting frequency counts for time=09051
# Extracting frequency counts for time=08241
# Extracting frequency counts for time=19101
# Extracting frequency counts for time=24172
# Extracting frequency counts for time=26011
# Extracting frequency counts for time=02151
# Extracting frequency counts for time=03233
# Extracting frequency counts for time=27040
# Extracting frequency counts for time=12220
# Extracting frequency counts for time=17260
# Extracting frequency counts for time=14050
# Extracting frequency counts for time=28110
# Extracting frequency counts for time=20183
# Extracting frequency counts for time=26301
# Extracting frequency counts for time=03202
# Extracting frequency counts for time=30292
# Extracting frequency counts for time=15153
# Extracting frequency counts for time=15150
# Extracting frequency counts for time=30252
# Extracting frequency counts for time=30250
# Extracting frequency counts for time=29232
# Extracting frequency counts for time=14061
# Extracting frequency counts for time=14102
# Extracting frequency counts for time=35013
# Extracting frequency counts for time=19120
# Extracting frequency counts for time=11181
# Extracting frequency counts for time=18023
# Extracting frequency counts for time=05040
# Extracting frequency counts for time=02101
# Extracting frequency counts for time=31022
# Extracting frequency counts for time=52023
# Extracting frequency counts for time=25231
# Extracting frequency counts for time=02100
# Extracting frequency counts for time=01042
# Extracting frequency counts for time=31041
# Extracting frequency counts for time=31030
# Extracting frequency counts for time=37151
# Extracting frequency counts for time=04300
# Extracting frequency counts for time=03200
# Extracting frequency counts for time=36050
# Extracting frequency counts for time=05310
# Extracting frequency counts for time=08240
# Extracting frequency counts for time=25201
# Extracting frequency counts for time=25230
# Extracting frequency counts for time=31020
# Extracting frequency counts for time=05053
# Extracting frequency counts for time=36070
# Extracting frequency counts for time=02162
# Extracting frequency counts for time=05011
# Extracting frequency counts for time=33201
# Extracting frequency counts for time=26020
# Extracting frequency counts for time=14073
# Extracting frequency counts for time=34283
# Extracting frequency counts for time=11143
# Extracting frequency counts for time=28133
# Extracting frequency counts for time=33173
# Extracting frequency counts for time=10082
# Extracting frequency counts for time=34261
# Extracting frequency counts for time=32131
# Extracting frequency counts for time=02111
# Extracting frequency counts for time=05033
# Extracting frequency counts for time=30293
# Extracting frequency counts for time=34230
# Extracting frequency counts for time=22032
# Extracting frequency counts for time=18043
# Extracting frequency counts for time=27102
# Extracting frequency counts for time=30251
# Extracting frequency counts for time=18081
# Extracting frequency counts for time=03232
# Extracting frequency counts for time=14042
# Extracting frequency counts for time=30262
# Extracting frequency counts for time=04290
# Extracting frequency counts for time=34272
# Extracting frequency counts for time=27080
# Extracting frequency counts for time=29180
# Extracting frequency counts for time=27083
# Extracting frequency counts for time=20222
# Extracting frequency counts for time=08223
# Extracting frequency counts for time=19140
# Extracting frequency counts for time=30260
# Extracting frequency counts for time=23071
# Extracting frequency counts for time=26292
# Extracting frequency counts for time=06091
# Extracting frequency counts for time=33213
# Extracting frequency counts for time=03183
# Extracting frequency counts for time=27043
# Extracting frequency counts for time=17263
# Extracting frequency counts for time=13023
# Extracting frequency counts for time=32122
# Extracting frequency counts for time=23081
# Extracting frequency counts for time=27071
# Extracting frequency counts for time=03203
# Extracting frequency counts for time=35023
# Extracting frequency counts for time=14072
# Extracting frequency counts for time=30312
# Extracting frequency counts for time=32081
# Extracting frequency counts for time=32121
# Extracting frequency counts for time=22021
# Extracting frequency counts for time=31031
# Extracting frequency counts for time=15160
# Extracting frequency counts for time=36080
# Extracting frequency counts for time=29243
# Extracting frequency counts for time=11202
# Extracting frequency counts for time=24163
# Extracting frequency counts for time=27062
# Extracting frequency counts for time=28123
# Extracting frequency counts for time=14100
# Extracting frequency counts for time=05061
# Extracting frequency counts for time=12222
# Extracting frequency counts for time=15142
# Extracting frequency counts for time=33160
# Extracting frequency counts for time=05062
# Extracting frequency counts for time=11203
# Extracting frequency counts for time=17302
# Extracting frequency counts for time=21271
# Extracting frequency counts for time=25210
# Extracting frequency counts for time=26032
# Extracting frequency counts for time=04243
# Extracting frequency counts for time=13012
# Extracting frequency counts for time=14081
# Extracting frequency counts for time=26302
# Extracting frequency counts for time=20173
# Extracting frequency counts for time=07162
# Extracting frequency counts for time=02143
# Extracting frequency counts for time=15152
# Extracting frequency counts for time=11173
# Extracting frequency counts for time=16183
# Extracting frequency counts for time=14052
# Extracting frequency counts for time=29200
# Extracting frequency counts for time=36093
# Extracting frequency counts for time=25200
# Extracting frequency counts for time=20180
# Extracting frequency counts for time=18082
# Extracting frequency counts for time=09280
# Extracting frequency counts for time=16230
# Extracting frequency counts for time=24192
# Extracting frequency counts for time=20211
# Extracting frequency counts for time=33192
# Extracting frequency counts for time=26270
# Extracting frequency counts for time=29230
# Extracting frequency counts for time=37153
# Extracting frequency counts for time=07183
# Extracting frequency counts for time=36110
# Extracting frequency counts for time=01051
# Extracting frequency counts for time=21243
# Extracting frequency counts for time=02153
# Extracting frequency counts for time=23113
# Extracting frequency counts for time=13283
# Extracting frequency counts for time=06110
# Extracting frequency counts for time=20160
# Extracting frequency counts for time=06122
# Extracting frequency counts for time=04292
# Extracting frequency counts for time=36061
# Extracting frequency counts for time=37161
# Extracting frequency counts for time=07190
# Extracting frequency counts for time=33152
# Extracting frequency counts for time=13022
# Extracting frequency counts for time=28130
# Extracting frequency counts for time=01040
# Extracting frequency counts for time=04283
# Extracting frequency counts for time=16243
# Extracting frequency counts for time=26293
# Extracting frequency counts for time=15172
# Extracting frequency counts for time=22033
# Extracting frequency counts for time=06111
# Extracting frequency counts for time=30283
# Extracting frequency counts for time=28150
# Extracting frequency counts for time=13310
# Extracting frequency counts for time=05311
# Extracting frequency counts for time=12253
# Extracting frequency counts for time=30303
# Extracting frequency counts for time=08213
# Extracting frequency counts for time=11140
# Extracting frequency counts for time=14101
# Extracting frequency counts for time=28142
# Extracting frequency counts for time=03210
# Extracting frequency counts for time=31073
# Extracting frequency counts for time=04263
# Extracting frequency counts for time=05023
# Extracting frequency counts for time=12213
# Extracting frequency counts for time=34262
# Extracting frequency counts for time=07143
# Extracting frequency counts for time=30270
# Extracting frequency counts for time=04272
# Extracting frequency counts for time=17292
# Extracting frequency counts for time=19150
# Extracting frequency counts for time=36081
# Extracting frequency counts for time=35021
# Extracting frequency counts for time=05010
# Extracting frequency counts for time=03170
# Extracting frequency counts for time=37122
# Extracting frequency counts for time=27042
# Extracting frequency counts for time=37133
# Extracting frequency counts for time=23060
# Extracting frequency counts for time=33153
# Extracting frequency counts for time=25252
# Extracting frequency counts for time=04270
# Extracting frequency counts for time=10113
# Extracting frequency counts for time=19103
# Extracting frequency counts for time=21273
# Extracting frequency counts for time=34221
# Extracting frequency counts for time=35042
# Extracting frequency counts for time=09040
# Extracting frequency counts for time=19132
# Extracting frequency counts for time=20182
# Extracting frequency counts for time=27073
# Extracting frequency counts for time=15121
# Extracting frequency counts for time=27061
# Extracting frequency counts for time=29223
# Extracting frequency counts for time=13292
# Extracting frequency counts for time=05032
# Extracting frequency counts for time=27093
# Extracting frequency counts for time=01031
# Extracting frequency counts for time=02102
# Extracting frequency counts for time=07182
# Extracting frequency counts for time=17290
# Extracting frequency counts for time=52012
# Extracting frequency counts for time=04301
# Extracting frequency counts for time=04242
# Extracting frequency counts for time=26272
# Extracting frequency counts for time=29241
# Extracting frequency counts for time=32102
# Extracting frequency counts for time=06072
# Extracting frequency counts for time=22313
# Extracting frequency counts for time=20163
# Extracting frequency counts for time=16220
# Extracting frequency counts for time=16231
# Extracting frequency counts for time=33190
# Extracting frequency counts for time=13280
# Extracting frequency counts for time=34241
# Extracting frequency counts for time=01050
# Extracting frequency counts for time=02122
# Extracting frequency counts for time=17272
# Extracting frequency counts for time=33181
# Extracting frequency counts for time=29231
# Extracting frequency counts for time=37163
# Extracting frequency counts for time=04281
# Extracting frequency counts for time=03220
# Extracting frequency counts for time=06082
# Extracting frequency counts for time=26290
# Extracting frequency counts for time=29233
# Extracting frequency counts for time=02123
# Extracting frequency counts for time=10071
# Extracting frequency counts for time=27053
# Extracting frequency counts for time=02103
# Extracting frequency counts for time=22010
# Extracting frequency counts for time=26271
# Extracting frequency counts for time=15143
# Extracting frequency counts for time=12263
# Extracting frequency counts for time=08243
# Extracting frequency counts for time=12233
# Extracting frequency counts for time=35293
# Extracting frequency counts for time=15113
# Extracting frequency counts for time=09020
# Extracting frequency counts for time=20161
# Extracting frequency counts for time=31011
# Extracting frequency counts for time=01060
# Extracting frequency counts for time=36073
# Extracting frequency counts for time=03213
# Extracting frequency counts for time=19122
# Extracting frequency counts for time=21292
# Extracting frequency counts for time=21231
# Extracting frequency counts for time=12273
# Extracting frequency counts for time=34222
# Extracting frequency counts for time=09063
# Extracting frequency counts for time=30302
# Extracting frequency counts for time=07202
# Extracting frequency counts for time=25223
# Extracting frequency counts for time=33162
# Extracting frequency counts for time=12272
# Extracting frequency counts for time=23073
# Extracting frequency counts for time=13293
# Extracting frequency counts for time=02112
# Extracting frequency counts for time=15141
# Extracting frequency counts for time=16242
# Extracting frequency counts for time=19143
# Extracting frequency counts for time=21283
# Extracting frequency counts for time=29221
# Extracting frequency counts for time=37131
# Extracting frequency counts for time=02141
# Extracting frequency counts for time=25242
# Extracting frequency counts for time=11142
# Extracting frequency counts for time=18021
# Extracting frequency counts for time=01072
# Extracting frequency counts for time=03221
# Extracting frequency counts for time=19141
# Extracting frequency counts for time=16181
# Extracting frequency counts for time=20162
# Extracting frequency counts for time=08253
# Extracting frequency counts for time=20172
# Extracting frequency counts for time=14091
# Extracting frequency counts for time=12251
# Extracting frequency counts for time=06112
# Extracting frequency counts for time=17301
# Extracting frequency counts for time=25213
# Extracting frequency counts for time=16241
# Extracting frequency counts for time=20212
# Extracting frequency counts for time=11141
# Extracting frequency counts for time=06073
# Extracting frequency counts for time=14082
# Extracting frequency counts for time=05031
# Extracting frequency counts for time=11161
# Extracting frequency counts for time=09021
# Extracting frequency counts for time=20210
# Extracting frequency counts for time=36072
# Extracting frequency counts for time=20221
# Extracting frequency counts for time=24143
# Extracting frequency counts for time=19152
# Extracting frequency counts for time=19142
# Extracting frequency counts for time=09050
# Extracting frequency counts for time=06070
# Extracting frequency counts for time=17262
# Extracting frequency counts for time=26023
# Extracting frequency counts for time=22053
# Extracting frequency counts for time=28151
# Extracting frequency counts for time=19123
# Extracting frequency counts for time=17300
# Extracting frequency counts for time=15131
# Extracting frequency counts for time=21260
# Extracting frequency counts for time=17011
# Extracting frequency counts for time=06131
# Extracting frequency counts for time=11193
# Extracting frequency counts for time=08270
# Extracting frequency counts for time=16223
# Extracting frequency counts for time=37162
# Extracting frequency counts for time=02160
# Extracting frequency counts for time=35010
# Extracting frequency counts for time=28172
# Extracting frequency counts for time=27091
# Extracting frequency counts for time=26021
# Extracting frequency counts for time=03222
# Extracting frequency counts for time=26031
# Extracting frequency counts for time=09022
# Extracting frequency counts for time=22043
# Extracting frequency counts for time=32130
# Extracting frequency counts for time=06080
# Extracting frequency counts for time=18031
# Extracting frequency counts for time=16200
# Extracting frequency counts for time=23072
# Extracting frequency counts for time=04282
# Extracting frequency counts for time=12223
